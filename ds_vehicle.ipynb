# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
# # Reviewer's feedback v.1
#
# **Halo Annas!**
#
# **Greetings from Chamdani**
#
# Perkenalkan saya Chamdani, disini saya akan mereview proyek kamu ya.
#
# Saya akan memberikan beberapa komentar dan feedback seperti dibawah ini, **mohon jangan dipindah, dirubah, maupun dihapus ya :).**
#
# > Saya akan menuliskan komentar saya **SEKALI**. Jadi apabila ada temuan atau kesalahan yang sama namun tidak ada komentar perbaikan disana, itu berarti kamu masih tetap harus memperbaikinya yaa.
#
# Komen yang saya berikan akan muncul dalam warna hijau, kuning, atau pun merah seperti ini:
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Ada beberapa catatan.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Perlu beberapa perbaikan.
#
# </div>

# %% [markdown]
# <div style="border:solid gray 5px; padding: 20px" class="alert alert-warning">
#
# **INGATLAH**
# * Project kamu tidak akan bisa diterima bila kamu masih memiliki feedback berwarna merah.
# * Kamu hanya memiliki 3 kali kesempatan iterasi submission disetiap projectnya
# * Kamu dapat memperbaiki dan menyelesaikan feedback dari saya tidak lebih dari 1\*24 jam setiap iterasinya. *Jika merasa kesulitan kamu dapat menuliskan responmu atas feedback saya menggunakan blok markdown warna biru.*

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-warning">
#
# # General feedback [Minor Improvement Needed]
#
# Terima kasih banyak telah mengirimkan proyek Anda!
#
# <br>
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Namun saya melihat masih banyak hal yang perlu di perbaiki. Saya telah menemukan beberapa kesalahan kecil yang cukup mudah kamu perbaiki. Hanya sedikit kesalahan kode dan kuranganya penjelasan dari setiap proses serta insight yang didapatkan dalam project ini. Saya yakin kamu dapat memperbaikinya dengan mudah.
#
# Saya telah meninggalkan komentar yang dapat membantu Anda meningkatkan proyek dan mengembangkan keterampilan Anda lebih lanjut. Hal ini tidak berarti bahwa Anda telah melakukan sesuatu yang salah. Hal ini hanya berisi beberapa saran tentang bagaimana pekerjaan Anda dapat diperbaiki. Anda masih memiliki kesempatan untuk memperbaikinya dan jangan lupa untuk kembali kepada saya setelah perbaikan anda selesai.
#
# <br>
# Jika ada sesuatu yang membuat Anda bingung atau tidak mengerti. Tolong, jangan ragu untuk menghubungi saya kapan saja jika Anda memiliki kesulitan.
#
# kamu bisa menghubungi saya melalui reply feedback di notebook ini yaa
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-success">
#
# # General feedback v.2 *Project Accepted*
#
# Terima kasih banyak telah mengirimkan proyek Anda!
# <br>
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Semoga apa yang kamu pelajari dalam project ini dapat membantu meningkatkan kemampuanmu. Pertahankan apa yang sudah bagus, dan tingkatkan apa yang menurutmu masih perlu ditingkatkan. Semoga berhasil pada project selanjutnya yaa :)
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-info">
# <b>Chamdani's info v.1</b> <a class="tocSkip"></a>
#
#
# Sebagai saran untuk project selanjutnya agara graph plot kamu lebih informatif dan lebih baik lagi kamu bisa menambahkan anotasi seperti pada contoh gambar berikut:
#
# ![image-2.png](attachment:image-2.png)
#
# Dan terkadang grafik kita memiliki posisi gambar yang cukup berdekatran oleh karena itu kita bisa membuat sedikit rotasi pada label value pada setiap plot seperti contoh berikut:
#
# ![image-3.png](attachment:image-3.png)
#
# Bacalah referensi berikut ini yaa:
#
# * https://stackoverflow.com/questions/39519609/annotate-bars-with-values-on-pandas-on-seaborn-factorplot-bar-plot
# * https://www.geeksforgeeks.org/how-to-annotate-bars-in-barplot-with-matplotlib-in-python/
#
#
# Contoh kode: *kamu bisa memperbaiki kode ini untuk kamu gunakan pada project selanjutnya*
#
# ```python
# #membuat visualisi untuk game rilis pertahun
# plt.figure(figsize=(25,20)) # contoh kode saya perbesar figure size nya
# splot = sns.barplot(data=year_group, x='year', y='name') # assign plot kedalam object
# #contoh kode anotasi mulai
# for g in splot.patches:
#     splot.annotate(format(g.get_height(), '.1f'),
#                    (g.get_x() + g.get_width() / 2., g.get_height()),
#                    ha = 'center', va = 'center', # posisi label value vertical dan horizontal berada pada certer plot
#                    xytext = (0, 20), rotation=45, # memutar label value pada plot 45 derajat dan memberi jara 20 pixel dari plot
#                    textcoords = 'offset points')
# #contoh kode anotasi selesai
# plt.xticks(rotation = 45) # memutar label x axis 45 derajat
# plt.show()
# ```
#
# </div>

# %% [markdown]
# # Faktor Apakah yang Menjual Sebuah Mobil?
#
# Anda adalah seorang analis di Crankshaft List. Ratusan iklan kendaraan gratis ditayangkan di situs web Anda setiap hari. Anda perlu mempelajari kumpulan data selama beberapa tahun terakhir dan menentukan faktor-faktor yang memengaruhi harga sebuah kendaraan.

# %% [markdown]
# # Konten <a id='back'></a>
#
# * [Pendahuluan](#intro)
# * [Pra-premrosesan](#pre-dataprocessing)
#     * [Memuat Data](#data_load)
#     * [Mengeksplor Data Awal](#data_explore)
#     * [Kesimpulan dan Langkah-Langkah Selanjutnya](#conclusion)
#     * [Mengatasi Nilai-Nilai yang Hilang](#missing_values)
#     * [Memperbaiki Tipe Data](#data_type)
#     * [Memperbaiki Kualitas Data](#data_quality)
#     * [Memeriksa Data yang Sudah Bersih](#data_cleansing)
# * [Mempelajari Parameter Inti](#parameter)
#     * [Mempelajari dan Menangani Outlier](#outlier)
#     * [Mempelajari Parameter Inti Tanpa Outlier](#without_outlier)
#     * [Masa Berlaku Iklan](#ads_periode)
#     * [Harga Rata-Rata Setiap Jenis Kendaraan](#average_price)
#     * [Faktor Harga](#price_factor)
# * [Kesimpulan Umum](#general_conclusion)

# %% [markdown]
# ## Pendahuluan <a id='intro'></a>
# Setiap kali kita melakukan penelitian, kita perlu merumuskan hipotesis yang kemudian dapat kita uji. Terkadang kita menerima hipotesis ini, tetapi terkadang kita juga menolaknya. Untuk membuat keputusan yang tepat, sebuah bisnis harus dapat memahami apakah asumsi yang dibuatnya benar atau tidak.
#
# Perusahaan Crankshat List membutuhkan data untuk menentukan faktor-faktor yang mempengaruhi harga sebuah kendaraan berdasarkan iklan kendaraan gratis yang ditayangkan di situs web. Data tersebut adalah data selama beberapa tahun terakhir.
#
# ### Tujuan:
# Menguji tiga hipotesis:
# 1. Mencari faktor-faktor yang mempengaruhi harga kendaraan dari parameter umur kendaraan, jarak tempuh, transmission, dan warna kendaraan.
# 2. Mencari harga rata-rata setiap jenis kendaraan.
# 3. Mencara rata-rata hari untuk iklan yang ditayangkan.
#
# ### Tahapan
# Data tentang kendaraan dengan iklan yang ditayangkan disimpan dalam file `/datasets/vehicles_us.csv'.csv`. Data tersebut masih data mentah, perlu diperbaiki kualitas datanya.
#
#  Berikut langkah-langkahnya untuk mencapai tujuan proyek:
#  1. Membaca Data Mentah
#  2. Pra-pemrosesan Data
#  3. Menangani Outlier
#  4. Menguji Data Bersih
#
#
# [Kembali ke Daftar Isi](#back)

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# **INGATLAH** pada setiap project kamu harus menghapus komentar yang kami tinggalkan dalam kurung siku `[]` seperiti diatas. Sebelum kamu menghapusnya pastikan kamu sudah memberikan penjelasan sesuai yang diminta dalam perintah kurung kotak tersebut.
#
# > Saya tidak akan memberikan komentar lagi terkait ini, itu artinya kamu perlu mastikan kamu sudah melakukan rekomendasi yang saya berikan pada seluruh bagian proyek ini.
#
# </div>

# %% [markdown]
# ## Pra-pemrosesan

# %%
# Muat semua library
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ### Memuat Data

# %%
# Muat file data menjadi DataFrame
df = pd.read_csv('/datasets/vehicles_us.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ### Mengeksplorasi Data Awal

# %% [markdown]
# *Dataset* Anda berisi kolom-kolom berikut:
#
#
# - `price`
# - `model_year`
# - `model`
# - `condition`
# - `cylinders`
# - `fuel` — gas, disel, dan lain-lain.
# - `odometer` — jarak tempuh kendaraan saat iklan ditayangkan
# - `transmission`
# - `paint_color`
# - `is_4wd` — apakah kendaraan memiliki penggerak 4 roda (tipe Boolean)
# - `date_posted` — tanggal iklan ditayangkan
# - `days_listed` — jumlah hari iklan ditayangkan hingga dihapus
# [Pahami kolom-kolomnya, lakukan eksplorasi data agar Anda terbiasa dengan data tersebut.]

# %%
# tampilkan informasi/rangkuman umum tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# tampilkan sampel data
df.head(5)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
df.tail(5)
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 51520    automatic  sedan       black     NaN  2018-10-03           37
# 51521    automatic  sedan       white     NaN  2018-11-14           22
# 51522    automatic  sedan        blue     NaN  2018-11-15           32
# 51523    automatic  sedan       black     NaN  2018-07-02           71
# 51524    automatic  sedan         NaN     NaN  2018-06-05           10

# %%
df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  47906.000000  46265.000000   43633.000000  25572.0
# mean    12132.464920   2009.750470      6.125235  115553.461738      1.0
# std     10040.803015      6.282065      1.660360   65094.611341      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2006.000000      4.000000   70000.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  113000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  155000.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - min price = 1 dan kemungkinan ada outlier
# - min odometer = 0 dan kemungkinan ada outlier
# - min day_listed = 0
#
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Tidak ada nilai duplikat
#
# </div>

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# *Type Data
#
# - model_year masih float seharusnya int
# - cylinder masih float seharusnya int
# - odometer masih float seharusnya int
# - is_4wd masih float seharusnya int / bool
# - date_posted masih float seharusnya date
#
# </div>

# %%
df.isnull().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False) / df.shape[0] * 100
# Out:
# is_4wd          50.369723
# paint_color     17.985444
# odometer        15.316836
# cylinders       10.208637
# model_year       7.023775
# price            0.000000
# model            0.000000
# condition        0.000000
# fuel             0.000000
# transmission     0.000000
# type             0.000000
# date_posted      0.000000
# days_listed      0.000000
# dtype: float64

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# *Bernilai NaN
#
# - model_year ~7%
# - cylinder ~10%
# - odometer ~15%
# - paint_color ~17%
# - is_4wd ~50%
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ### Kesimpulan dan Langkah-Langkah Selanjutnya

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Memperbaiki statistika deskriptif di kolom price, odometer, dan day_listed dan menghilangkan outlier
# - Tidak ada nilai duplikat jadi tidak perlu menghapus nilai duplikat
# - Memperbaiki tipe data di kolom model_year, cylinder, is_4wd, dan date_posted
# - Memperbaiki nilai NaN di kolom model_year, cylinder, odometer, paint_color, dan is_4wd
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Mengatasi Nilai-Nilai yang Hilang (Jika Ada)

# %%
#Fumgsi mengisi nilai hilang dengan mean
def mean_missing_value(dataframe, agg_column, value_column):
    grouped_values = dataframe.groupby(agg_column)[value_column].mean().reset_index()
    size = len(grouped_values)
    for i in range(size):
        group = grouped_values[agg_column][i]
        value = grouped_values[value_column][i]
        dataframe.loc[(dataframe[agg_column] == group) & (dataframe[value_column].isna()), value_column] = value
    return dataframe

# %%
#Fumgsi mengisi nilai hilang dengan median
def median_missing_value(dataframe, agg_column, value_column):
    grouped_values = dataframe.groupby(agg_column)[value_column].median().reset_index()
    size = len(grouped_values)
    for i in range(size):
        group = grouped_values[agg_column][i]
        value = grouped_values[value_column][i]
        dataframe.loc[(dataframe[agg_column]==group) & (dataframe[value_column].isna()), value_column] = value
    return dataframe

# %%
df['model_year'].value_counts()
# Out:
# 2013.0    3549
# 2012.0    3468
# 2014.0    3448
# 2011.0    3375
# 2015.0    3323
#           ...
# 1948.0       1
# 1961.0       1
# 1936.0       1
# 1949.0       1
# 1955.0       1
# Name: model_year, Length: 68, dtype: int64

# %%
df['model_year'].sort_values().unique()
# Out:
# array([1908., 1929., 1936., 1948., 1949., 1954., 1955., 1958., 1960.,
#        1961., 1962., 1963., 1964., 1965., 1966., 1967., 1968., 1969.,
#        1970., 1971., 1972., 1973., 1974., 1975., 1976., 1977., 1978.,
#        1979., 1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987.,
#        1988., 1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996.,
#        1997., 1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005.,
#        2006., 2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014.,
#        2015., 2016., 2017., 2018., 2019.,   nan])

# %%
df = mean_missing_value(df, 'model', 'model_year')

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Pengisian nilai kosong di model_year berdasarkan kelompok model menggunakan mean karena dari tabel deskriptif sebelumnya mean di kolom model_year bernilai sekitar 2009 dan median bernilai 2011. Jadi kemungkinan kecil ada outlier.
#
# </div>

# %%
df['cylinders'].value_counts()
# Out:
# 8.0     15844
# 6.0     15700
# 4.0     13864
# 10.0      549
# 5.0       272
# 3.0        34
# 12.0        2
# Name: cylinders, dtype: int64

# %%
df['cylinders'].sort_values().unique()
# Out:
# array([ 3.,  4.,  5.,  6.,  8., 10., 12., nan])

# %%
df = mean_missing_value(df, 'model', 'cylinders')

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Pengisian nilai kosong di cylinders berdasarkan kelompok model menggunakan mean karena dari tabel deskriptif sebelumnya mean di cylinders bernilai sekitar 6,1 dan median bernilai 6. Jadi kemungkinan kecil ada outlier.
#
# </div>

# %%
df['odometer'].value_counts()
# Out:
# 0.0         185
# 140000.0    183
# 120000.0    179
# 130000.0    178
# 160000.0    167
#            ...
# 280499.0      1
# 49814.0       1
# 194920.0      1
# 140800.0      1
# 269527.0      1
# Name: odometer, Length: 17762, dtype: int64

# %%
df['odometer'].unique()
# Out:
# array([145000.,  88705., 110000., ..., 121778., 181500., 139573.])

# %%
df = median_missing_value(df, 'model_year', 'odometer')

# %%
df[df['odometer'].isnull()]
# Out:
#        price  model_year       model condition  cylinders fuel  odometer  \
# 45694  18000      1929.0  ford f-150      good        8.0  gas       NaN
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 45694       manual  other      silver     NaN  2018-11-18           59

# %%
df.groupby('model_year')['odometer'].median()
# Out:
# model_year
# 1908.000000    169328.0
# 1929.000000         NaN
# 1936.000000     30000.0
# 1948.000000      4000.0
# 1949.000000      1800.0
#                  ...
# 2016.000000     54000.0
# 2017.000000     41000.0
# 2017.414557     27493.0
# 2018.000000     20627.0
# 2019.000000     14151.5
# Name: odometer, Length: 167, dtype: float64

# %%
df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  51525.000000  51525.000000   51524.000000  25572.0
# mean    12132.464920   2009.749939      6.124281  115194.162856      1.0
# std     10040.803015      6.096916      1.644649   62117.195345      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2007.000000      4.000000   73370.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  114000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  152862.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %%
odometer_median = df['model_year'] == 1929
df.loc[odometer_median, 'odometer'] = df.loc[odometer_median, 'odometer'].fillna(114000)

# %%
df[df['model_year'] == 1929]
# Out:
#        price  model_year       model condition  cylinders fuel  odometer  \
# 45694  18000      1929.0  ford f-150      good        8.0  gas  114000.0
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 45694       manual  other      silver     NaN  2018-11-18           59

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Pengisian nilai kosong di odometer berdasarkan kelompok model_year menggunakan median karena dari tabel deskriptif sebelumnya mean di cylinders bernilai sekitar 115,553 dan median bernilai 113,000. Jadi kemungkinan besar ada outlier.
# - Perlu diperhatikan pada model_year dengan tahun 1929 walaupun sudah melakukan fungsi nilainya masih NaN, untuk itu perlu diisi secara manual menggunakan median tabel deskriptif.
#
# </div>

# %%
df['paint_color'].value_counts()
# Out:
# white     10029
# black      7692
# silver     6244
# grey       5037
# blue       4475
# red        4421
# green      1396
# brown      1223
# custom     1153
# yellow      255
# orange      231
# purple      102
# Name: paint_color, dtype: int64

# %%
df['paint_color'].sort_values().unique()
# Out:
# array(['black', 'blue', 'brown', 'custom', 'green', 'grey', 'orange',
#        'purple', 'red', 'silver', 'white', 'yellow', nan], dtype=object)

# %%
df['paint_color'] = df['paint_color'].fillna('unknown')

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Pengisian nilai kosong di paint_color untuk sementara diisi 'unknown' karena data tersebut data kualitatif dan tidak ada hubungan dengan kelompok kolom lain.
#
# </div>

# %%
df['is_4wd'].value_counts()
# Out:
# 1.0    25572
# Name: is_4wd, dtype: int64

# %%
df['is_4wd'].sort_values().unique()
# Out:
# array([ 1., nan])

# %%
df['is_4wd'] = df['is_4wd'].fillna(0)

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Pengisian nilai kosong di is_4wd diisi 0 karena kolom tersebut bernilai boolean, maka selain 1 nilainya adalah 0.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Memperbaiki Tipe Data

# %%
df['model_year'] = df['model_year'].astype('int')

# %%
df['model_year'].sort_values().unique()
# Out:
# array([1908, 1929, 1936, 1948, 1949, 1954, 1955, 1958, 1960, 1961, 1962,
#        1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019])

# %%
df['cylinders'] = df['cylinders'].astype('int')

# %%
df['odometer'] = df['odometer'].astype('int')

# %%
df['is_4wd'] = df['is_4wd'].astype('bool')

# %%
df['date_posted'] = pd.to_datetime(df['date_posted'])

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - model_year dari float menjadi int
# - cylinders dari float menjadi int
# - odometer dari float menjadi boolean
# - is_4wd dari float menjadi boolean
# - date_posted dari float menjadi datetime
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Kerja bagus!
#
# </div>

# %% [markdown]
# ## Memperbaiki Kualitas Data

# %%
# Tambahkan nilai waktu dan tanggal pada saat iklan ditayangkan 
df['week_posted'] = df['date_posted'].dt.weekday

# %%
df['month_posted'] = df['date_posted'].dt.month

# %%
df['year_posted'] = df['date_posted'].dt.year

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Menambahkan kolom week_posted, month_posted, dan year_posted berdasarkan date_posted
#
# </div>

# %%
# Tambahkan usia kendaraan saat iklan ditayangkan
df['vehicle_age'] = df['year_posted'] - df['model_year']

# %%
df[df['vehicle_age']==0]
# Out:
#        price  model_year                        model  condition  cylinders  \
# 19     13990        2018              hyundai elantra  excellent          4
# 71     23300        2018  nissan frontier crew cab sv       good          6
# 78     23800        2019  nissan frontier crew cab sv       good          6
# 99     39950        2018          chevrolet silverado  excellent          8
# 106    21500        2019  nissan frontier crew cab sv       good          6
# ...      ...         ...                          ...        ...        ...
# 51376  27890        2018                     ram 1500  excellent          8
# 51442  28990        2018                    ford f150  excellent          7
# 51446  15999        2018             chevrolet malibu  excellent          4
# 51447  33990        2019                     ram 1500  excellent          8
# 51504  20481        2018                 toyota camry   like new          4
#
# ...

# %%
#logs['source'] = logs['source'].replace('', 'email')
df['vehicle_age'] = df['vehicle_age'].replace(0, 1)

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %%
df[df['vehicle_age']==0]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, week_posted, month_posted, year_posted, vehicle_age]
# Index: []

# %%
# Tambahkan jarak tempuh rata-rata kendaraan per tahun 
df['average_odometer'] = df['odometer'] / df['vehicle_age']

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Menambahkan kolom vehicle_age yang didapat dari (year_posted - model_year)
# - Menambahkan kolom average_odometer yang didapat dari (odometer / vehicle_age)
# - Perlu diperhatikan pada saat vehivle_age adalah 0, dan menambahkan average_odometer nilanya menjadi infinity
# - Sehigga perlu dilakukan replace pada vehicle_age yang bernilai 0 menjadi 1
#
# </div>

# %%
# Mungkin membantu untuk mengganti nilai pada kolom 'condition' dengan sesuatu yang dapat dimanipulasi dengan lebih mudah 
def get_condition_level(values):
    if values == 'new':
        return 5
    elif values == 'like new':
        return 4
    elif values == 'excelent':
        return 3
    elif values == 'good':
        return 2
    elif values == 'fair':
        return 1
    else:
        return 0

# %%
df['condition_level'] = df['condition'].apply(get_condition_level)

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Memeriksa Data yang Sudah Bersih

# %%
# tampilkan informasi/rangkuman umum tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             51525 non-null  int64
#  1   model_year        51525 non-null  int64
#  2   model             51525 non-null  object
#  3   condition         51525 non-null  object
#  4   cylinders         51525 non-null  int64
#  5   fuel              51525 non-null  object
#  6   odometer          51525 non-null  int64
#  7   transmission      51525 non-null  object
#  8   type              51525 non-null  object
#  9   paint_color       51525 non-null  object
#  10  is_4wd            51525 non-null  bool
#  11  date_posted       51525 non-null  datetime64[ns]
#  12  days_listed       51525 non-null  int64
#  13  week_posted       51525 non-null  int64
#  14  month_posted      51525 non-null  int64
#  15  year_posted       51525 non-null  int64
# ...

# %%
# tampilkan sampel data 
df.sample(10)
# Out:
#        price  model_year                          model  condition  cylinders  \
# 31240  39500        2017                  toyota tundra   like new          8
# 3041   26900        2016                       ram 3500       good          8
# 2401   11950        2004     chevrolet silverado 2500hd       good          8
# 16465  17999        2012                  dodge charger  excellent          8
# 11013  12500        2000           ford f350 super duty       good          8
# 21682  16950        2010                      ford f150  excellent          8
# 2550    8995        2011                    ford escape  excellent          6
# 37473   5995        2006                 subaru outback       good          4
# 30616   4300        2006                chevrolet tahoe  excellent          7
# 4181   23900        2014  chevrolet silverado 1500 crew       good          8
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Mempelajari Parameter Inti
# *Parameternya adalah
# - Harga
# - Usia kendaraan ketika iklan ditayangkan
# - Jarak tempuh
# - Jumlah silinder
# - Kondisi

# %%
df[df['price'] == 375000]
# Out:
#         price  model_year            model condition  cylinders fuel  \
# 12504  375000        1999  nissan frontier      good          6  gas
#
#        odometer transmission    type paint_color  is_4wd date_posted  \
# 12504    115000    automatic  pickup        blue    True  2018-05-19
#
#        days_listed  week_posted  month_posted  year_posted  vehicle_age  \
# 12504           21            5             5         2018           19
#
#        average_odometer  condition_level
# 12504       6052.631579                2

# %%
#Histogram Price
df.hist('price', bins=30, range=(0,70000))
plt.show()

# %%
#Histogram vehicle_age
df.hist('vehicle_age', bins=50, range=(0, 60) )
plt.show()

# %%
#Histogram odometer
df.hist('odometer', bins=100)
plt.show()

# %%
#Histogram cylinders
df.hist('cylinders', bins=50)
plt.show()

# %%
#Histogram condition
df.hist('condition_level', bins=50)
plt.show()

# %%
df_filter = df.query('2000 <= price <= 50000')

# %%
#Histogram Price Filter Tabel
df_filter.hist('price', bins=50, range=(0,60000))
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah dengan histogram price bisa dilihat ada kendaraan seharga 1, ini tidak masuk akal
# - Perusahaan menentukan harga 2000 adalah harga minimal
# - Dan mulai dari harga 50000 nilainya melandai, sisa nilai tersebut mungkin adalah outlier.
# - Untuk memperbaiki itu, perlu dilakukan filter tabel dari harga 2000 sampai 50000.
#
# </div>

# %%
df_filter = df_filter.query('vehicle_age < 30')

# %%
#Histogram vehicle_age Filter Tabel
df_filter.hist('vehicle_age', bins=50, range=(0, 60) )
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah dengan histogram vehicle_age, dimulai dari umur 30, nilainya melandai. Diatas 30 mungkin adalah outlier
# - Untuk memperbaiki itu, perlu dilakukan filter tabel dari umur kurang dari 30
#
# </div>

# %%
df_filter = df_filter.query('odometer < 300000')

# %%
#Histogram average_odomter Filter Tabel
df_filter.hist('odometer', bins=50)
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah dengan histogram odometer, dimulai dari odometer 300000, nilainya melandai. Diatas 300000 mungkin adalah outlier
# - Ada nilai 0 berarti kendaraan tersebut tidak pernah dipakai atau kendaraan baru
#
# </div>

# %%
#Histogram cylinders Filter Tabel
df_filter.hist('cylinders', bins=50)
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# Mobil biasanya bermesin 3,4,5,6,8,10,12,16 silinder. Untuk mobil penumpang, mesin dengan 3, 4, 6 silinder lebih umum. Secara umum, makin banyaknya silinder, makin tingginya kelas mobil. Jadi tidak perlu dilakukan filter untuk kolom cylinder
#
# </div>

# %%
percent_miss = 100 - (df_filter.shape[0] / df.shape[0] * 100)

# %%
print('Data mentah yang hilang setelah membuat df_filter sekitar ~',percent_miss, "%")
# Out:
# Data mentah yang hilang setelah membuat df_filter sekitar ~ 6.8976225133430376 %

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Mempelajari dan Menangani Outlier

# %%
# Tentukan batas bawah dan batas atas outlier 
df_filter.boxplot('price')
plt.show()

# %%
q1_price = df_filter['price'].quantile(0.25)
q3_price = df_filter['price'].quantile(0.75)
iqr_price = q3_price - q1_price
lower_whisker_price = q1_price - (1.5 * iqr_price)
upper_whisker_price = q3_price + (1.5 * iqr_price)
print('Lower Whisker Price adalah', lower_whisker_price)
print('Upper Whisker Price adalah', upper_whisker_price)
# Out:
# Lower Whisker Price adalah -11005.0
# Upper Whisker Price adalah 33795.0

# %%
df_new = df_filter[(df_filter['price']>lower_whisker_price) & (df_filter['price']<upper_whisker_price)]

# %%
df_new.boxplot('price')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent! Namun lihatlah kamu masih memiliki outlier pada boxplot yang kamu tampilkan. Hal ini bisa disebabkan karena kamu hanya menjalankan proses pananganan data outlier hanya 1x. Untuk itu kamu bisa menanganinya dengan menjalankan proses penanganan data outlier yang sama beberapa kali hingga data outlier benar2 terhandle dengan baik.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Sudah diperbaiki di boxplot dibawah, price tidak ada outlier lagi
#
# </div>

# %%
q1_price = df_new['price'].quantile(0.25)
q3_price = df_new['price'].quantile(0.75)
iqr_price = q3_price - q1_price
lower_whisker_price = q1_price - (1.5 * iqr_price)
upper_whisker_price = q3_price + (1.5 * iqr_price)
print('Lower Whisker Price adalah', lower_whisker_price)
print('Upper Whisker Price adalah', upper_whisker_price)
# Out:
# Lower Whisker Price adalah -10242.5
# Upper Whisker Price adalah 31737.5

# %%
df_new = df_filter[(df_filter['price']>lower_whisker_price) & (df_filter['price']<upper_whisker_price)]

# %%
df_new.boxplot('price')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %%
df_new['price'].describe()
# Out:
# count    45943.000000
# mean     11419.982522
# std       7253.231968
# min       2000.000000
# 25%       5500.000000
# 50%       9400.000000
# 75%      15990.000000
# max      31700.000000
# Name: price, dtype: float64

# %%
df_new[df_new['price'] >= 31000]
# Out:
#        price  model_year                          model  condition  cylinders  \
# 177    31400        2016  chevrolet silverado 1500 crew       good          8
# 746    31000        2018        jeep wrangler unlimited  excellent          6
# 1008   31269        2017                gmc sierra 1500  excellent          8
# 1751   31552        2018                  ford explorer  excellent          6
# 2012   31200        2014                  ford f-250 sd       good          8
# ...      ...         ...                            ...        ...        ...
# 48512  31594        2015                gmc sierra 1500  excellent          8
# 48758  31500        2007                      ford f350  excellent          8
# 50174  31400        2016  chevrolet silverado 1500 crew       good          8
# 50714  31000        2015                     ford f-150  excellent          8
# 50949  31499        2012                       ram 3500       good          6
#
# ...

# %%
df_new.query('price >=31000 and condition == "fair"')
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, week_posted, month_posted, year_posted, vehicle_age, average_odometer, condition_level]
# Index: []

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - df_filter boxplot menunjukkan ada outlier di sekitar diatas harga 33000
# - Kemudian membuat dataframe baru df_new yang menghapus outlier tersebut
# - df_new masih ada outlier disekitar harga diatas 31000 tetapi berdasarkan tabel deskriptif mobil dengan harga tersebut tidak ada kondisi fair maupun salvage
#
# </div>

# %%
df_filter.boxplot('vehicle_age')
plt.show()

# %%
q1_vehicle_age = df_new['vehicle_age'].quantile(0.25)
q3_vehicle_age = df_new['vehicle_age'].quantile(0.75)
iqr_vehicle_age = q3_vehicle_age - q1_vehicle_age
lower_whisker_vehicle_age = q1_vehicle_age - (1.5 * iqr_vehicle_age)
upper_whisker_vehicle_age = q3_vehicle_age + (1.5 * iqr_vehicle_age)
print('Lower Whisker vehicle_age adalah', lower_whisker_vehicle_age)
print('Upper Whisker vehicle_age adalah', upper_whisker_vehicle_age)
# Out:
# Lower Whisker vehicle_age adalah -5.5
# Upper Whisker vehicle_age adalah 22.5

# %%
df_new = df_new[(df_new['vehicle_age']>lower_whisker_vehicle_age) & (df_new['vehicle_age']<upper_whisker_vehicle_age)]

# %%
df_new.boxplot('vehicle_age')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent! Namun lihatlah kamu masih memiliki outlier pada boxplot yang kamu tampilkan. Hal ini bisa disebabkan karena kamu hanya menjalankan proses pananganan data outlier hanya 1x. Untuk itu kamu bisa menanganinya dengan menjalankan proses penanganan data outlier yang sama beberapa kali hingga data outlier benar2 terhandle dengan baik.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Sudah diperbaiki di boxplot dibawah, vehicle_age tidak ada outlier lagi
#
# </div>

# %%
q1_vehicle_age = df_new['vehicle_age'].quantile(0.25)
q3_vehicle_age = df_new['vehicle_age'].quantile(0.75)
iqr_vehicle_age = q3_vehicle_age - q1_vehicle_age
lower_whisker_vehicle_age = q1_vehicle_age - (1.5 * iqr_vehicle_age)
upper_whisker_vehicle_age = q3_vehicle_age + (1.5 * iqr_vehicle_age)
print('Lower Whisker vehicle_age adalah', lower_whisker_vehicle_age)
print('Upper Whisker vehicle_age adalah', upper_whisker_vehicle_age)
# Out:
# Lower Whisker vehicle_age adalah -4.0
# Upper Whisker vehicle_age adalah 20.0

# %%
df_new = df_new[(df_new['vehicle_age']>lower_whisker_vehicle_age) & (df_new['vehicle_age']<upper_whisker_vehicle_age)]

# %%
df_new.boxplot('vehicle_age')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %%
df_new['vehicle_age'].describe()
# Out:
# count    44641.000000
# mean         8.092628
# std          4.492033
# min          1.000000
# 25%          5.000000
# 50%          8.000000
# 75%         11.000000
# max         19.000000
# Name: vehicle_age, dtype: float64

# %%
df_new.query('vehicle_age > 20')
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, week_posted, month_posted, year_posted, vehicle_age, average_odometer, condition_level]
# Index: []

# %%
df_new.query('vehicle_age > 20 and condition == "fair"')
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, week_posted, month_posted, year_posted, vehicle_age, average_odometer, condition_level]
# Index: []

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - df_new['vehicle_age'] menghapus outlier dari umur kendaraan diatas 22.5 tahun.
# - Masih ada outlier diatas umur 20 tahun, dan jika difilter berdasarkan kondisi masih banyak yang kondisinya fair
# - Mungkin ada keterkaitan semakin lama umur kendaraan semakin kondisinya berkurang
#
# </div>

# %%
df_filter.boxplot('odometer')
plt.show()

# %%
q1_odometer = df_new['odometer'].quantile(0.25)
q3_odometer = df_new['odometer'].quantile(0.75)
iqr_odometer = q3_odometer - q1_odometer
lower_whisker_odometer = q1_odometer - (1.5 * iqr_odometer)
upper_whisker_odometer = q3_odometer + (1.5 * iqr_odometer)
print('Lower Whisker odometer adalah', lower_whisker_odometer)
print('Upper Whisker odometer adalah', upper_whisker_odometer)
# Out:
# Lower Whisker odometer adalah -30581.0
# Upper Whisker odometer adalah 260339.0

# %%
df_new = df_new[(df_new['odometer']>lower_whisker_odometer) & (df_new['odometer']<upper_whisker_odometer)]

# %%
df_new.boxplot('odometer')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent! Namun lihatlah kamu masih memiliki outlier pada boxplot yang kamu tampilkan. Hal ini bisa disebabkan karena kamu hanya menjalankan proses pananganan data outlier hanya 1x. Untuk itu kamu bisa menanganinya dengan menjalankan proses penanganan data outlier yang sama beberapa kali hingga data outlier benar2 terhandle dengan baik.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Sudah diperbaiki di boxplot dibawah, odometer tidak ada outlier lagi
#
# </div>

# %%
q1_odometer = df_new['odometer'].quantile(0.25)
q3_odometer = df_new['odometer'].quantile(0.75)
iqr_odometer = q3_odometer - q1_odometer
lower_whisker_odometer = q1_odometer - (1.5 * iqr_odometer)
upper_whisker_odometer = q3_odometer + (1.5 * iqr_odometer)
print('Lower Whisker odometer adalah', lower_whisker_odometer)
print('Upper Whisker odometer adalah', upper_whisker_odometer)
# Out:
# Lower Whisker odometer adalah -30215.0
# Upper Whisker odometer adalah 259729.0

# %%
df_new = df_new[(df_new['odometer']>lower_whisker_odometer) & (df_new['odometer']<upper_whisker_odometer)]

# %%
df_new.boxplot('odometer')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %%
df_new['odometer'].describe()
# Out:
# count     44220.000000
# mean     114116.336318
# std       53244.058071
# min           0.000000
# 25%       78514.000000
# 50%      115000.000000
# 75%      151000.000000
# max      259352.000000
# Name: odometer, dtype: float64

# %%
df_new.query('odometer > 260000 and condition == "fair"')
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, week_posted, month_posted, year_posted, vehicle_age, average_odometer, condition_level]
# Index: []

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - df_new['odometer'] menghapus outlier dari jarak tempuh diatas 262229
# - Masih ada outlier diatas umur 260000, dan jika difilter berdasarkan kondisi hanya ada 2 yang kondisinya fair
# - Jadi mobil dengan odometer tersebut masih cukup layak dijual
#
# </div>

# %%
df_filter.boxplot('cylinders')
plt.show()

# %%
df_new.boxplot('cylinders')
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - df_filter dan df_new untuk cylinders menunjukkan kemungkinan kecil ada outlier
#
# </div>

# %%
df_filter.boxplot('condition_level')
plt.show()

# %%
df_new.boxplot('condition_level')
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - df_filter dan df_new untuk condition_level menunjukkan kemungkinan kecil ada outlier
#
# </div>

# %%
percent_miss_new = 100 - (df_new.shape[0] / df.shape[0] * 100)

# %%
print('Data mentah yang hilang setelah membuat df_new sekitar ~',percent_miss_new, "%")
# Out:
# Data mentah yang hilang setelah membuat df_new sekitar ~ 14.177583697234354 %

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Mempelajari Parameter Inti Tanpa Outlier

# %%
df_new.describe()
df_new.head(5)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2009      ford f-150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
# 5  14990        2014    chrysler 300  excellent          6  gas     57954
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV     unknown    True  2018-06-23           19
# 1    automatic  pickup       white    True  2018-10-19           50
# 2    automatic   sedan         red   False  2019-02-07           79
# 4    automatic   sedan       black   False  2019-04-02           28
# 5    automatic   sedan       black    True  2018-06-20           15
#
#    week_posted  month_posted  year_posted  vehicle_age  average_odometer  \
# ...

# %%
df['price'].hist(bins=50, range=(0,60000))
df_new['price'].hist(bins=50, range=(0,60000))
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah untuk price masih ada harga 0 s/d 2000, dan harga diatas 33000an
# - Setelah difilter harga tersebut tidak ada
# </div>

# %%
df['vehicle_age'].hist(bins=50, range=(0,60))
df_new['vehicle_age'].hist(bins=50, range=(0,60))
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah untuk vehicle_age dengan data yang tidak difilter tidak jauh berbeda
# - Perbedaan yang mencolok adalah data yang difilter sudah tidak ada lagi umur kendaraan diatas 22 tahun
# </div>

# %%
df['odometer'].hist(bins=50, range=(0,300000))
df_new['odometer'].hist(bins=50, range=(0,300000))
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Data mentah untuk odometer dengan data yang tidak difilter juga tidak jauh berbeda
# - Perbedaan yang mencolok adalah data yang difilter sudah tidak ada lagi jarak temput diatas 262000
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Masa Berlaku Iklan

# %%
df_new['days_listed'].describe()
# Out:
# count    44220.000000
# mean        39.569833
# std         28.215855
# min          0.000000
# 25%         19.000000
# 50%         33.000000
# 75%         53.000000
# max        271.000000
# Name: days_listed, dtype: float64

# %%
df_new['days_listed'].hist(bins=50)
plt.show()

# %%
df_new.boxplot('days_listed')
plt.show()

# %%
q1_days_listed = df_new['days_listed'].quantile(0.25)
q3_days_listed = df_new['days_listed'].quantile(0.75)
iqr_days_listed = q3_days_listed - q1_days_listed
lower_whisker_days_listed = q1_days_listed - (1.5 * iqr_days_listed)
upper_whisker_days_listed = q3_days_listed + (1.5 * iqr_days_listed)
print('Lower Whisker days_listed adalah', lower_whisker_days_listed)
print('Upper Whisker days_listed adalah', upper_whisker_days_listed)
# Out:
# Lower Whisker days_listed adalah -32.0
# Upper Whisker days_listed adalah 104.0

# %%
df_new.query('days_listed > 104').shape[0]
# Out:
# 1387

# %%
df_new.loc[df_new['days_listed'] == 0].shape[0]
df_new.query('days_listed == 0').shape[0]
# Out:
# 46

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Iklan rata-rata ditayangkan 33 sampai 39 hari.
# - Ada mobil yang langsung terjual setelah iklan ditayangkan, jumlahnya 46 mobil
# - Mobil paling lama dijual yaitu diatas 104 hari, jumlahnya ada 1426 mobil
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent! Namun lihatlah kamu masih memiliki outlier pada boxplot yang kamu tampilkan. Hal ini bisa disebabkan karena kamu hanya menjalankan proses pananganan data outlier hanya 1x. Untuk itu kamu bisa menanganinya dengan menjalankan proses penanganan data outlier yang sama beberapa kali hingga data outlier benar2 terhandle dengan baik.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Sudah diperbaiki di boxplot dibawah, days_listed tidak ada outlier lagi
#
# </div>

# %%
df_new = df_new[(df_new['days_listed']>lower_whisker_days_listed) & (df_new['days_listed']<upper_whisker_days_listed)]

# %%
df_new.boxplot('days_listed')
plt.show()

# %%
q1_days_listed = df_new['days_listed'].quantile(0.25)
q3_days_listed = df_new['days_listed'].quantile(0.75)
iqr_days_listed = q3_days_listed - q1_days_listed
lower_whisker_days_listed = q1_days_listed - (1.5 * iqr_days_listed)
upper_whisker_days_listed = q3_days_listed + (1.5 * iqr_days_listed)
print('Lower Whisker days_listed adalah', lower_whisker_days_listed)
print('Upper Whisker days_listed adalah', upper_whisker_days_listed)
# Out:
# Lower Whisker days_listed adalah -31.5
# Upper Whisker days_listed adalah 100.5

# %%
df_new = df_new[(df_new['days_listed']>lower_whisker_days_listed) & (df_new['days_listed']<upper_whisker_days_listed)]

# %%
df_new.boxplot('days_listed')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Harga Rata-Rata Setiap Jenis Kendaraan

# %%
df_new['price'].describe()
# Out:
# count    42548.000000
# mean     11638.163298
# std       7277.980659
# min       2000.000000
# 25%       5800.000000
# 50%       9750.000000
# 75%      15999.000000
# max      31700.000000
# Name: price, dtype: float64

# %%
pivot_type = df_new.pivot_table(index=['type'], values=['date_posted', 'price'], aggfunc={'date_posted':'count', 'price':'median'})
pivot_type = pivot_type.rename(columns={
    'date_posted' : 'count_date_posted',
    'price' : 'median_price'
}).sort_values(by='count_date_posted', ascending=False)

# %%
pivot_type
# Out:
#              count_date_posted  median_price
# type
# sedan                    10639          6500
# SUV                      10511          8995
# truck                     9712         14995
# pickup                    5531         14500
# coupe                     1697         15700
# wagon                     1361          7995
# mini-van                  1025          6995
# hatchback                  912          6000
# van                        505          7990
# convertible                279         13900
# other                      212          8999
# offroad                    143         14500
# bus                         21         28990

# %%
pivot_type.plot(kind='bar', grid=True)
plt.show()

# %%
pivot_type.plot(x='count_date_posted', y='median_price', kind='scatter', grid=True)
plt.show()

# %%
pivot_type['count_date_posted'].corr(pivot_type['median_price'])
# Out:
# -0.1838930916891236

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Scatter plot pivot_type menunjukkan jumlah ikan dari 0 sampai dibawah 2000, median pricenya bermacam macam
# - Di jumlah iklan 6000 sampai 11000 an median pricenya sekitar 15000
# - Di jumlah iklan diatas 11000 an median pricenya berkisar 5000 sampai 1000
# - Korelasi jumlah iklan ditayangkan dengan median price yaitu -0,15, hampir mendekati 0 yang artianya korelasinya sangat lemah
# - Tabel pivot_type dan bar chart menunjukkan 2 kendaraan dengan jumlah iklan yang paling banyak adalah SUV dan Sedan
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Faktor Harga

# %%
df_new_suv = df_new[df_new['type'] == 'SUV'].reset_index(drop=True)

# %%
df_new_suv.shape[0]
# Out:
# 10511

# %%
df_new_suv.corr()['price']
# Out:
# price               1.000000
# model_year          0.658505
# cylinders           0.015115
# odometer           -0.612220
# is_4wd              0.130511
# days_listed        -0.015273
# week_posted         0.016324
# month_posted        0.000792
# year_posted        -0.004462
# vehicle_age        -0.654259
# average_odometer    0.269655
# condition_level    -0.008266
# Name: price, dtype: float64

# %%
df_new_suv_cor = df_new_suv[['price', 'vehicle_age', 'odometer', 'condition_level', 'transmission', 'paint_color']]
#df_new_suv_cor

# %%
group_data = ['price', 'vehicle_age', 'odometer', 'condition_level', 'transmission', 'paint_color']
for group_data in df_new_suv_cor:
    df_new_suv_cor.plot(x='price', y=group_data, kind='scatter', grid=True)

# %%
df_new_suv.groupby('transmission')['date_posted'].count()
# Out:
# transmission
# automatic    10036
# manual         390
# other           85
# Name: date_posted, dtype: int64

# %%
df_new_suv_paint = df_new_suv.groupby('paint_color')['date_posted'].count().sort_values(ascending=False)
df_new_suv_paint
# Out:
# paint_color
# unknown    1887
# black      1833
# white      1649
# silver     1389
# grey       1040
# blue        894
# red         768
# green       333
# brown       317
# custom      253
# orange       77
# yellow       38
# purple       33
# Name: date_posted, dtype: int64

# %%
df_new_suv_2 = df_new_suv.loc[(df_new_suv['paint_color'] != 'yellow') & (df_new_suv['paint_color'] != 'purple')]
df_new_suv_2['paint_color'].value_counts()
# Out:
# unknown    1887
# black      1833
# white      1649
# silver     1389
# grey       1040
# blue        894
# red         768
# green       333
# brown       317
# custom      253
# orange       77
# Name: paint_color, dtype: int64

# %%
df_new_suv_2
df_new_suv_2.plot(x='price', y='paint_color', kind='scatter', grid=True)
plt.show()

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# *Korelasi harga dengan beberapa hal untuk mobil type SUV
#
# - Korelasi price dengan vehicle_age adalah -0,6 (Negatif Korelasi Kuat) , artinya jika price makin tinggi maka vehicle_age makin rendah, ini bisa dibuktikan pada scatter dimana banyak kendaraan diumur 20an harganya sekitar 5000an, dan dengan harga 35000an maksimal umur kendaraan adalah 12 tahunan
# - Korelasi price dengan odometer adalah -0, 6 (Negatif Korelasi Kuat), artinya jika price makin tinggi maka odometernya maskin rendah, bisa dilihat juga di scatter
# - Korelasi price dengan condition_level, transmission, dan paint_color sangat lemah
#
# </div>

# %%
df_new_sedan = df_new[df_new['type'] == 'sedan'].reset_index(drop=True)

# %%
df_new_sedan.shape[0]
# Out:
# 10639

# %%
df_new_sedan.corr()['price']
# Out:
# price               1.000000
# model_year          0.690556
# cylinders           0.014533
# odometer           -0.632364
# is_4wd              0.107751
# days_listed        -0.003041
# week_posted         0.000660
# month_posted       -0.013883
# year_posted         0.014939
# vehicle_age        -0.679906
# average_odometer    0.280467
# condition_level     0.001706
# Name: price, dtype: float64

# %%
df_new_sedan_cor = df_new_sedan[['price', 'vehicle_age', 'odometer', 'condition_level', 'transmission', 'paint_color']]

# %%
for group_data in df_new_sedan_cor:
    df_new_sedan_cor.plot(x='price', y=group_data, kind='scatter', grid=True)

# %%
df_new_sedan.groupby('transmission')['date_posted'].count()
# Out:
# transmission
# automatic    10092
# manual         481
# other           66
# Name: date_posted, dtype: int64

# %%
df_new_sedan_paint = df_new_sedan.groupby('paint_color')['date_posted'].count().sort_values(ascending=False)
df_new_sedan_paint
# Out:
# paint_color
# unknown    1898
# silver     1814
# black      1577
# grey       1481
# white      1314
# blue       1075
# red         808
# custom      241
# brown       221
# green       166
# purple       20
# yellow       16
# orange        8
# Name: date_posted, dtype: int64

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# - Korelasi harga dengan beberapa hal untuk mobil type Sedan mirip dengan korelasi pada mobil type SUV
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %% [markdown]
# ## Kesimpulan Umum

# %% [markdown]
# <div style="background-color:rgba(0, 255, 172, 0.07)"
#
# *Data Mentah (df)
# - Tidak ada nilai duplikat
# - Nilai yang hilang ada di model_year, cylinder, odometer,  paint_color, dan is_4wd
# - Mengatasi nilai yang hilang dengan fungsi median dan mean, khusu kolom paint_color diisi unknown,
# dan is_4wd dengan 0
# - Memperbaiki type data untuk model__year, cylinder, odomter, is_4wd, dan date_posted
#
# *Data Bersih (df_new)
# - Menghapus outlier di kolom price, vehicle_age, odometer untuk analisa yang lebih baik
# - Membandingkan histogram data mentah dengan data bersih
#
# *Tujuan tugas ini adalah mencari faktor yang mempengaruhi harga kendaraan, dari scatter yang dibuat dapat disimpulkan :
# - Korelasi price dengan vehicle_age adalah -0,6 (Negatif Korelasi Kuat)
# - Korelasi price dengan odometer adalah -0, 6 (Negatif Korelasi Kuat)
# - Korelasi price dengan condition_level, transmission, dan paint_color sangat lemah
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>
